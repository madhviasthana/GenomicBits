# %%
from bit_encoding import *
from python_libraries import *
from data_loading import *

# %%
from bit_encoding import *
from python_libraries import *
from data_loading import *
data_path="/Users/madhviasthana/Documents/Bioninformatics Git Repo/task-1-hamming-distance-histogram-madhviasthana/data/queries.txt"
import argparse
from hamminghist import *


# Define file paths
db_path = "/Users/madhviasthana/Documents/Bioninformatics Git Repo/task-1-hamming-distance-histogram-madhviasthana/data/database.txt"
query_path = "/Users/madhviasthana/Documents/Bioninformatics Git Repo/task-1-hamming-distance-histogram-madhviasthana/data/queries.txt"


# 2 Bit-Encoding
kmer_length = 16
encoded_array = efficient_bit_encoding(data_path, kmer_length)
print(encoded_array.shape)

# Task 1: Hamming Distance
process_histogram_from_encoded(encoded_array, encoded_array, 20)
# Out:
# (11,)
# Query 0 Histogram:
# Distance 0.0 - 2.0: 1
# Distance 2.0 - 4.0: 4
# Distance 4.0 - 6.0: 6
# Distance 6.0 - 8.0: 0
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 1 Histogram:
# Distance 0.0 - 2.0: 2
# Distance 2.0 - 4.0: 3
# Distance 4.0 - 6.0: 5
# Distance 6.0 - 8.0: 1
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 2 Histogram:
# Distance 0.0 - 2.0: 1
# Distance 2.0 - 4.0: 3
# Distance 4.0 - 6.0: 4
# Distance 6.0 - 8.0: 3
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 3 Histogram:
# Distance 0.0 - 2.0: 1
# Distance 2.0 - 4.0: 5
# Distance 4.0 - 6.0: 5
# Distance 6.0 - 8.0: 0
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 4 Histogram:
# Distance 0.0 - 2.0: 2
# Distance 2.0 - 4.0: 5
# Distance 4.0 - 6.0: 3
# Distance 6.0 - 8.0: 1
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 5 Histogram:
# Distance 0.0 - 2.0: 3
# Distance 2.0 - 4.0: 4
# Distance 4.0 - 6.0: 3
# Distance 6.0 - 8.0: 1
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 6 Histogram:
# Distance 0.0 - 2.0: 3
# Distance 2.0 - 4.0: 3
# Distance 4.0 - 6.0: 4
# Distance 6.0 - 8.0: 1
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 7 Histogram:
# Distance 0.0 - 2.0: 1
# Distance 2.0 - 4.0: 5
# Distance 4.0 - 6.0: 4
# Distance 6.0 - 8.0: 1
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 8 Histogram:
# Distance 0.0 - 2.0: 1
# Distance 2.0 - 4.0: 7
# Distance 4.0 - 6.0: 3
# Distance 6.0 - 8.0: 0
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 9 Histogram:
# Distance 0.0 - 2.0: 2
# Distance 2.0 - 4.0: 3
# Distance 4.0 - 6.0: 6
# Distance 6.0 - 8.0: 0
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
# Query 10 Histogram:
# Distance 0.0 - 2.0: 2
# Distance 2.0 - 4.0: 4
# Distance 4.0 - 6.0: 5
# Distance 6.0 - 8.0: 0
# Distance 8.0 - 10.0: 0
# Distance 10.0 - 12.0: 0
# Distance 12.0 - 14.0: 0
# Distance 14.0 - 16.0: 0
# Distance 16.0 - 18.0: 0
# Distance 18.0 - 20.0: 0
